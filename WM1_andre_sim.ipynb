# %%
# %load_ext autoreload
# %autoreload 2
from qiskit_metal import draw, Dict, designs, MetalGUI
from qiskit_metal.toolbox_metal import math_and_overrides
from qiskit_metal.qlibrary.core import QComponent
import qiskit_metal as metal
# ?metal.qlibrary.core.QComponent.add_qgeometry

design = metal.designs.design_planar.DesignPlanar()
gui = metal.MetalGUI(design)
design.overwrite_enabled = True

# dir(QComponent)
cpw_width = '11.7um'

design._chips.main.size.size_x = '5mm'
design._chips.main.size.size_y = '5mm'
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.terminations.short_to_ground import ShortToGround
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors
from qiskit_metal.qlibrary.tlines.mixed_path import RouteMixed
from qiskit_metal.qlibrary.qubits.transmon_cross import TransmonCross
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee
from qiskit_metal.qlibrary.couplers.cap_n_interdigital_tee import CapNInterdigitalTee
from qiskit_metal.qlibrary.couplers.line_tee import LineTee

from collections import OrderedDict

import numpy as np
### Top and Bottom
options = Dict(
    orientation = -90,
    pos_y = 2.5 - 0.3,
    # pad_width = '80um',
    # pad_length = '200um',
    # taper_height = '200um',
    trace_width = cpw_width,
    trace_gap = '5.1um'
)
wb1 = LaunchpadWirebond(design, 'wb_top', options=options)

options = Dict(
    orientation = 90,
    pos_y = -2.5 + 0.3,
    # pad_width = '80um',
    # pad_length = '200um',
    # taper_height = '200um',
    trace_width = cpw_width,
    trace_gap = '5.1um'
)
wb2 = LaunchpadWirebond(design, 'wb_bottom', options=options)

xmon1_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '215um',
                 ground_spacing = '10um', 
                 claw_gap = '5.1um', 
                 claw_width = '15um',
                #  claw_cpw_length = 0
                 ),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30um',
    cross_length = '240um',
    cross_gap = '30um',
    orientation = '-90',
    pos_x = '-1500um',
    pos_y = '1200um',
    aedt_hfss_inductance = 9.686E-9
)

# Create a new Transmon Cross object with name 'Q1'
q1 = TransmonCross(design, 'Q1', options=xmon1_options)

# otg_options = dict(width = '5.85um', 
#                    gap = '5.1um', 
#                 #    termination_gap = '500um',
#                    pos_x='-30um',  
#                    pos_y='1313um', 
#                    orientation='90')

# otg = OpenToGround(design, 'open_to_ground', options=otg_options)


xmon3_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '185.9um',
                 ground_spacing = '4.1um', 
                 claw_gap = '5.1um', 
                 claw_width = '15.9um',
                #  claw_cpw_length = 0
                 ),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30.9um',
    cross_length = '200.9um',
    cross_gap = '29.1um',
    orientation = '90',
    pos_x = '2000.9um',
    pos_y = '1700um',
    aedt_hfss_inductance = 10.471E-9
)

# Create a new Transmon Cross object with name 'Q1'
q3 = TransmonCross(design, 'Q3', options=xmon3_options)

xmon5_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '185um',
                 ground_spacing = '5um', 
                 claw_gap = '5.1um', 
                 claw_width = '10um',
                #  claw_cpw_length = 0
                 ),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30um',
    cross_length = '200um',
    cross_gap = '30um',
    orientation = '-90',
    pos_x = '-2000um',
    pos_y = '-300um',
    aedt_hfss_inductance = 13.235E-9
)

# Create a new Transmon Cross object with name 'Q1'
q5 = TransmonCross(design, 'Q5', options=xmon5_options)


xmon2_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '215.9um',
                 ground_spacing = '9.1um', 
                 claw_gap = '5.1um', 
                 claw_width = '15.9um',
                #  claw_cpw_length = 0
                 ),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30.9um',
    cross_length = '240.9um',
    cross_gap = '29.1um',
    orientation = '90',
    pos_x = '1500um',
    pos_y = '250um',
    aedt_hfss_inductance = 11.268E-9
)

# Create a new Transmon Cross object with name 'Q1'
q2 = TransmonCross(design, 'Q2', options=xmon2_options)


xmon4_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '215.9um',
                 ground_spacing = '9.1um', 
                 claw_gap = '5.1um', 
                 claw_width = '15.9um',
                #  claw_cpw_length = '0'
                 ),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30.9um',
    cross_length = '240.9um',
    cross_gap = '29.1um',
    orientation = '-90',
    pos_x = '-1500um',
    pos_y = '-1500um',
    aedt_hfss_inductance = 13.816E-9
)

# Create a new Transmon Cross object with name 'Q1'
q4 = TransmonCross(design, 'Q4', options=xmon4_options)


xmon6_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '200.9um',
                 ground_spacing = '10.9um', 
                 claw_gap = '5.1um', 
                 claw_width = '10.9um',
                 claw_cpw_width = cpw_width,
                #  claw_cpw_length = '0'
                 ),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30.9um',
    cross_length = '220.9um',
    cross_gap = '29.1um',
    orientation = '90',
    pos_x = '2000um',
    pos_y = '-1200um',
    aedt_hfss_inductance = 12.679E-9
)

# Create a new Transmon Cross object with name 'Q1'
q6 = TransmonCross(design, 'Q6', options=xmon6_options)


clt1_opts = Dict(prime_width = cpw_width,
                prime_gap = '5.1um',
                second_width = cpw_width,
                second_gap = '5.1um',
                coupling_space = '7.9um',
                coupling_length = '225um',
                open_termination = False,
                orientation = '-90',
                pos_y = '1200um',
                down_length = '50um')

clt1 = CoupledLineTee(design, 'clt1', clt1_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw1_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'clt1',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q1',
                                                  pin = 'c')),
                lead = Dict(end_straight = '70um',
                            # start_jogged_extension = jogsS),
                ),
                fillet = '49.9um',
                total_length = '3900um',#'3893.8166um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um',)
cpw1 = RouteMeander(design, 'cpw1', options = cpw1_opts)


ncap3_opts = Dict(pos_x = '0',
                  pos_y = '1700um',
                  orientation = '90',
                  prime_width = cpw_width,
                  prime_gap = '5.1um',
                  second_width = cpw_width,
                  second_gap = '5.1um',
                  cap_gap = '4.1um',
                  cap_width = '10.9um',
                  cap_gap_ground = '5.1um',
                  finger_length = '30.9um',
                  finger_count = '10',
                  cap_distance = '50.9um',
                  )

NCap3 = CapNInterdigitalTee(design, 'ncap3', options = ncap3_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw3_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap3',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q3',
                                                  pin = 'c')),
                lead = Dict(start_straight = '100um',
                            end_straight = '170um'),
                fillet = '49.9um',
                total_length = '8150um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw3 = RouteMeander(design, 'cpw3', options = cpw3_opts)


ncap5_opts = Dict(pos_x = '0',
                  pos_y = '-300um',
                  orientation = '-90',
                  prime_width = cpw_width,
                  prime_gap = '5.1um',
                  second_width = cpw_width,
                  second_gap = '5.1um',
                  cap_gap = '4.1um',
                  cap_width = '10.9um',
                  cap_gap_ground = '5.1um',
                  finger_length = '30.9um',
                  finger_count = '7',
                  cap_distance = '50.9um',
                  )

NCap5 = CapNInterdigitalTee(design, 'ncap5', options = ncap5_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw5_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap5',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q5',
                                                  pin = 'c')),
                lead = Dict(start_straight = '100um'),
                fillet = '49.9um',
                total_length = '8025um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw5 = RouteMeander(design, 'cpw5', options = cpw5_opts)


clt2_opts = Dict(prime_width = cpw_width,
                prime_gap = '5.1um',
                second_width = cpw_width,
                second_gap = '5.1um',
                coupling_space = '7.9um',
                coupling_length = '225um',
                open_termination = False,
                orientation = '90',
                pos_y = '250um',
                down_length = '50um')

clt2 = CoupledLineTee(design, 'clt2', clt2_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw2_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'clt2',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q2',
                                                  pin = 'c')),
                lead = Dict(end_straight = '70um',
                            # start_jogged_extension = jogsS),
                ),
                fillet = '49.9um',
                total_length = '3700um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw2 = RouteMeander(design, 'cpw2', options = cpw2_opts)


clt4_opts = Dict(prime_width = cpw_width,
                prime_gap = '5.1um',
                second_width = cpw_width,
                second_gap = '5.1um',
                coupling_space = '7.9um',
                coupling_length = '225um',
                open_termination = False,
                orientation = '-90',
                pos_y = '-1500um',
                down_length = '50um')

clt4 = CoupledLineTee(design, 'clt4', clt4_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw4_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'clt4',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q4',
                                                  pin = 'c')),
                lead = Dict(start_straight = '10um',
                            end_straight = '70um'),
                #             ),
                fillet = '49.9um',
                total_length = '3550um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw4 = RouteMeander(design, 'cpw4', options = cpw4_opts)


ncap6_opts = Dict(pos_x = '0',
                  pos_y = '-1000um',
                  orientation = '90',
                  prime_width = cpw_width,
                  prime_gap = '5.1um',
                  second_width = cpw_width,
                  second_gap = '5.1um',
                  cap_gap = '4.1um',
                  cap_width = '10.9um',
                  cap_gap_ground = '5.1um',
                  finger_length = '30.9um',
                  finger_count = '4',
                  cap_distance = '50.9um',
                  )

NCap6 = CapNInterdigitalTee(design, 'ncap6', options = ncap6_opts)

cpw6_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap6',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q6',
                                                  pin = 'c')),
                lead = Dict(start_straight = '100um',
                            end_straight = '70um'),
                fillet = '49.9um',
                total_length = '8000um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw6 = RouteMeander(design, 'cpw6', options = cpw6_opts)


RouteStraight.get_template_options(design)
feedline_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'wb_top',
                                                        pin = 'tie'),
                                       end_pin = Dict(component = 'wb_bottom',
                                                      pin = 'tie')),
                     trace_width = cpw_width,
                     trace_gap = '5.1um')
feedline = RouteStraight(design, 'feedline', options = feedline_opts)

# feedline_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap6',
#                                                         pin = 'prime_start'),
#                                        end_pin = Dict(component = 'ncap5',
#                                                       pin = 'prime_start')),
#                      trace_width = cpw_width,
#                      trace_gap = '5.1um')
# feedline2 = RouteStraight(design, 'feedline2', options = feedline_opts)

# feedline_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap5',
#                                                         pin = 'prime_end'),
#                                        end_pin = Dict(component = 'ncap4',
#                                                       pin = 'prime_end')),
#                      trace_width = cpw_width,
#                      trace_gap = '5.1um')
# feedline3 = RouteStraight(design, 'feedline3', options = feedline_opts)

# feedline_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap4',
#                                                         pin = 'prime_start'),
#                                        end_pin = Dict(component = 'wb_bottom',
#                                                       pin = 'tie')),
#                      trace_width = cpw_width,
#                      trace_gap = '5.1um')
# feedline4 = RouteStraight(design, 'feedline4', options = feedline_opts)
gui.rebuild()
gui.autoscale()
# gui.zoom_on_components(['clt5', 'Q5'])
# gui.screenshot()

# %% [markdown]
# # EPR Simulation (Qubit + Cavity)

# %%
from qiskit_metal.analyses.quantization import EPRanalysis
import pyEPR as epr

# %%
qubit_names = [f'Q{i}' for i in range(1,7)]
for name in qubit_names:
    Lj = design.components[name].options['aedt_hfss_inductance']
    design.components[name].options['hfss_inductance'] = Lj
design.rebuild()

# %%
#Simulate Q1 + bus coupling strength

eig_q12bus = EPRanalysis(design, "hfss")
hfss1 = eig_q12bus.sim.renderer
eig_q12bus.sim.setup.max_passes = 50
eig_q12bus.sim.setup.max_delta_f = 0.1
eig_q12bus.sim.setup.n_modes = 2
# hfss1.options['max_mesh_length']

# Create sim setup vars
sim_setup_var_dict = dict()
for i, name in enumerate(qubit_names):
    i += 1
    key_Lj = f'Lj{i}'
    key_Cj = f'Cj{i}'
    sim_setup_var_dict[key_Lj] = str(design.components[name].options['hfss_inductance']) + ' H'
    sim_setup_var_dict[key_Cj] = str(design.components[name].options['hfss_capacitance']) + ' F'

eig_q12bus.sim.setup.vars = sim_setup_var_dict

gui.rebuild()  # line needed to propagate the updates from the qubit instance into the junction design table
gui.autoscale()

# %%
# %matplotlib inline

hfss = eig_q12bus.sim.renderer

i = 4
# for i, name in enumerate(qubit_names):
#     i += 1

#     ### Run ANSYS simulation
#     # if i == 3 or i == 5 or i == 6:
#     #     open_terminations = [(f'cpw{i}', 'start')]
#     # else:
#     #     open_terminations = []

#     if i != 3:
#         continue
    
    # Clear previous design and renderer new design
eig_q12bus.sim.run(name="Q3RO_v5.0",
                    components=[f'Q{i}', f'cpw{i}', f'clt{i}' if i == 1 or i == 2 or i == 4 else f'ncap{i}'])

### Plot convergences
eig_q12bus.sim.plot_convergences()

### Run EPR Analysis
hfss1 = eig_q12bus.sim.renderer
pinfo1 = hfss1.pinfo

eprd1 = epr.DistributedAnalysis(pinfo1)

ℰ_elec = eprd1.calc_energy_electric()
ℰ_elec_substrate = eprd1.calc_energy_electric(None, 'main')
ℰ_mag = eprd1.calc_energy_magnetic()

print(f"""
ℰ_elec_all       = {ℰ_elec}
ℰ_elec_substrate = {ℰ_elec_substrate}
EPR of substrate = {ℰ_elec_substrate / ℰ_elec * 100 :.1f}%

ℰ_mag    = {ℰ_mag}
""")

eig_q12bus.sim.print_run_args()

eig_q12bus.setup.sweep_variable = f'Lj{i}'

eig_q12bus.setup.junctions = Dict()
eig_q12bus.setup.junctions[f'jj{i}'] = Dict(rect=f'JJ_rect_Lj_Q{i}_rect_jj', 
                                            line=f'JJ_Lj_Q{i}_rect_jj_',
                                            Lj_variable=f'Lj{i}', 
                                            Cj_variable=f'Cj{i}')

eig_q12bus.run_epr()

# %% [markdown]
# # LOM Analysis

# %%
qubit_names = [f'Q{i}' for i in range(1,7)]
for name in qubit_names:
    Lj = design.components[name].options['aedt_hfss_inductance']
    design.components[name].options['q3d_inductance'] = str(Lj) + "H"
design.rebuild()

# %%
from qiskit_metal.analyses.quantization import LOManalysis
c1 = LOManalysis(design, "q3d")

# %%
c1.sim.setup.reuse_selected_design = False
c1.sim.setup.reuse_setup = False

# example: update single setting
c1.sim.setup.max_passes = 30
c1.sim.setup.min_converged_passes = 1
c1.sim.setup.percent_error = 0.1

# import inspect
# inspect.signature(c1.sim.renderer.modeler.mesh_length)
# c1.sim.renderer.modeler.mesh_length('ground_strip_mesh', ['ground_main_plane'], MaxLength = '3um')
# c1.sim.renderer.modeler.mesh_length('claw_mesh', ['c_connector_arm_Q1'], MaxLength = '5um')
# c1.sim.renderer.modeler.mesh_length('cross_mesh', ['cross_Q1'], MaxLength = '10um')


# .mesh_length('ground_strip', ['ground_main_plane'], MaxLength = '0.003mm')
c1.sim.setup

# c1
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': False,
#  'reuse_setup': False,
#  'freq_ghz': 5.0,
#  'save_fields': False,
#  'enabled': True,
#  'max_passes': 30,
#  'min_passes': 2,
#  'min_converged_passes': 1,
#  'percent_error': 0.1,
#  'percent_refinement': 30,
#  'auto_increase_solution_order': True,
#  'solution_order': 'High',
#  'solver_type': 'Iterative'}

# %%
all_cap_matricies = []

for i, name in enumerate(qubit_names):
    i += 1
    # if i != 1:
    #     continue

    ### Render design
    # if i == 3 or i == 5 or i == 6: # Finger coupler
    #     selection = [f'Q{i}']
    #     open_pins = [(f'Q{i}', 'c')]
    # else: # Hanging resonator coupler
    #     selection = [f'Q{i}', f'cpw{i}', f'clt{i}']
    #     open_pins = [(f'clt{i}', 'prime_start'), (f'clt{i}', 'prime_end')]

    selection = [f'Q{i}']
    open_pins = [(f'Q{i}', 'c')]


    c1.sim.run(name = 'redo_LOMv1.0', components=selection,
               open_terminations=open_pins)
    cap_df = c1.sim.capacitance_matrix

    all_cap_matricies.append(cap_df)

    print(f'For Qubit {i}, the cap matrix is...')
    print(cap_df)
# Out:
# INFO 11:04AM [connect_project]: Connecting to Ansys Desktop API...
# INFO 11:04AM [load_ansys_project]: 	Opened Ansys App
# INFO 11:04AM [load_ansys_project]: 	Opened Ansys Desktop v2021.1.0
# INFO 11:04AM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/lfl/Documents/Ansoft/
# 	Project:   Project23
# INFO 11:04AM [connect_design]: 	Opened active design
# 	Design:    redo_LOMv1.0_q3d [Solution type: Q3D]
# INFO 11:04AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:04AM [connect]: 	Connected to project "Project23" and design "redo_LOMv1.0_q3d" 😀
#
# INFO 11:05AM [connect_design]: 	Opened active design
# 	Design:    redo_LOMv1.0_q3d1 [Solution type: Q3D]
# WARNING 11:05AM [connect_setup]: 	No design setup detected.
# WARNING 11:05AM [connect_setup]: 	Creating Q3D default setup.
# INFO 11:05AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:05AM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:05AM [analyze]: Analyzing setup Setup1
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpkrs4fuch.txt, C, , Setup1:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpkren7v3q.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp7vfwno1x.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpvi1zt3ya.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpxa3q_q_z.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpaqnmx6zi.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp7xpf1wd3.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmplc0_6rz7.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp_rpiolx2.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 8, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmphujbjz5j.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 9, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp8folre5b.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 10, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpyphl7z7y.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 11, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp0m1zzkse.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 12, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp6didydus.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 13, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpj7nvxy74.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 14, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpozbc300c.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 15, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp_p_67nw9.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 16, False
# INFO 11:07AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpgvf9ddwe.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 17, False
# For Qubit 1, the cap matrix is...
#                     c_connector_arm_Q1   cross_Q1  ground_main_plane
# c_connector_arm_Q1           115.66743   -5.79016         -109.32119
# cross_Q1                      -5.79016  125.97570         -117.94538
# ground_main_plane           -109.32119 -117.94538          282.24435
# INFO 11:07AM [connect_design]: 	Opened active design
# 	Design:    redo_LOMv1.0_q3d2 [Solution type: Q3D]
# WARNING 11:07AM [connect_setup]: 	No design setup detected.
# WARNING 11:07AM [connect_setup]: 	Creating Q3D default setup.
# INFO 11:07AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:07AM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:07AM [analyze]: Analyzing setup Setup1
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpshh5jgo8.txt, C, , Setup1:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp04_i85i9.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp_bdg_n8n.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpv951zl9s.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpfgh2o22y.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpkh4gdf3y.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpoykr5do2.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpgupzf1jp.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpkq9wl_hu.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 8, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpd1gusr49.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 9, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpzik9yyjr.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 10, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmphphws3o2.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 11, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpua5ubw3w.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 12, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp7sdx_rfr.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 13, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpnru7_5qn.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 14, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp39z9xjih.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 15, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpsla58mm9.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 16, False
# INFO 11:09AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpb1pn8o95.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 17, False
# For Qubit 2, the cap matrix is...
#                     c_connector_arm_Q2   cross_Q2  ground_main_plane
# c_connector_arm_Q2           117.50081   -6.39300         -110.52444
# cross_Q2                      -6.39300  128.69008         -120.03863
# ground_main_plane           -110.52444 -120.03863          285.50934
# INFO 11:10AM [connect_design]: 	Opened active design
# 	Design:    redo_LOMv1.0_q3d3 [Solution type: Q3D]
# WARNING 11:10AM [connect_setup]: 	No design setup detected.
# WARNING 11:10AM [connect_setup]: 	Creating Q3D default setup.
# INFO 11:10AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:10AM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:10AM [analyze]: Analyzing setup Setup1
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpjyh2a6pk.txt, C, , Setup1:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpbj_e6wv1.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpu_t2rlp7.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp7ots91tp.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpx2s2ykcd.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpogi831bk.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp57ual45o.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpggsuh_b7.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpjgcw41xn.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 8, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmprb_h_t6v.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 9, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpade3g2_y.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 10, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp8sc1hs8l.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 11, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpdodlab3t.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 12, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp1p9pfkau.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 13, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpe111bc4r.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 14, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpi0kosz1h.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 15, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpq9lke9zi.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 16, False
# INFO 11:12AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpph4regpg.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 17, False
# For Qubit 3, the cap matrix is...
#                     c_connector_arm_Q3   cross_Q3  ground_main_plane
# c_connector_arm_Q3           102.75494   -7.76120          -94.33631
# cross_Q3                      -7.76120  106.21251          -96.35904
# ground_main_plane            -94.33631  -96.35904          241.81374
# INFO 11:12AM [connect_design]: 	Opened active design
# 	Design:    redo_LOMv1.0_q3d4 [Solution type: Q3D]
# WARNING 11:12AM [connect_setup]: 	No design setup detected.
# WARNING 11:12AM [connect_setup]: 	Creating Q3D default setup.
# INFO 11:12AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:12AM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:12AM [analyze]: Analyzing setup Setup1
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpz7yve__t.txt, C, , Setup1:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpytlg_n_5.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpej0vu1bc.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp4cbdsukq.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpe238o2lq.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpfp2ws1ma.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp7dtll4wq.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpvg3mac6d.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpunyzzyp5.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 8, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpaj8mdm0h.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 9, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpe9x68aej.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 10, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmphxj11_l6.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 11, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpgcrwq23r.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 12, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpd92062ox.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 13, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp94nm53gq.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 14, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpv7x096i2.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 15, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpt__lbtva.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 16, False
# INFO 11:14AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpjbvj66jo.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 17, False
# For Qubit 4, the cap matrix is...
#                     c_connector_arm_Q4   cross_Q4  ground_main_plane
# c_connector_arm_Q4           117.50538   -6.39278         -110.52887
# cross_Q4                      -6.39278  128.69712         -120.04666
# ground_main_plane           -110.52887 -120.04666          285.53516
# INFO 11:14AM [connect_design]: 	Opened active design
# 	Design:    redo_LOMv1.0_q3d5 [Solution type: Q3D]
# WARNING 11:14AM [connect_setup]: 	No design setup detected.
# WARNING 11:14AM [connect_setup]: 	Creating Q3D default setup.
# INFO 11:14AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:15AM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:15AM [analyze]: Analyzing setup Setup1
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpjmpwf11v.txt, C, , Setup1:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmplz7w_htc.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmps8yoeb4s.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpcay5jbqy.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp94fmtkib.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp56iy5e9b.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpzr4r7owx.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpqkmmtvbf.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpjsk41sqy.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 8, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpg0s2s7rg.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 9, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp06zpg3zp.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 10, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpnp1xm7o_.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 11, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp5q68zrtv.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 12, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpbu9910zq.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 13, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmps7c71uhu.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 14, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp0_2htf_8.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 15, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmplyo9v3qg.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 16, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmph85hfj94.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 17, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp7pzmp3f3.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 18, False
# INFO 11:18AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpw912sigf.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 19, False
# For Qubit 5, the cap matrix is...
#                     c_connector_arm_Q5   cross_Q5  ground_main_plane
# c_connector_arm_Q5            89.67407   -5.60816          -83.61337
# cross_Q5                      -5.60816  104.11034          -96.41123
# ground_main_plane            -83.61337  -96.41123          231.04928
# INFO 11:18AM [connect_design]: 	Opened active design
# 	Design:    redo_LOMv1.0_q3d6 [Solution type: Q3D]
# WARNING 11:18AM [connect_setup]: 	No design setup detected.
# WARNING 11:18AM [connect_setup]: 	Creating Q3D default setup.
# INFO 11:18AM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:18AM [get_setup]: 	Opened setup `Setup1`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 11:18AM [analyze]: Analyzing setup Setup1
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpl9tpfp9s.txt, C, , Setup1:LastAdaptive, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpnq8bt6d7.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 1, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmproqxdjmj.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 2, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpf3puh0tv.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 3, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpxfz5xjqe.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 4, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpoa25dqx2.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 5, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpsd1itmrr.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 6, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp1fnjroa8.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 7, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpdu1s6ok9.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 8, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp5e7wnv0b.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 9, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp_awz87kg.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 10, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp8pkxvmbo.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 11, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpp1kqiz8l.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 12, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp6feruf8o.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 13, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp81fck9f4.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 14, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpoa8s0l52.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 15, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpd57iwb45.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 16, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpkqhjjcos.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 17, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp1d7e5j7d.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 18, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmp5cjh2uof.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 19, False
# INFO 11:22AM [get_matrix]: Exporting matrix data to (C:\Users\lfl\AppData\Local\Temp\tmpcp88vaga.txt, C, , Setup1:AdaptivePass, "Original", "ohm", "nH", "fF", "mSie", 5000000000, Maxwell, 20, False
# For Qubit 6, the cap matrix is...
#                     c_connector_arm_Q6   cross_Q6  ground_main_plane
# c_connector_arm_Q6           100.74945   -4.55200          -95.75720
# cross_Q6                      -4.55200  117.86233         -111.17214
# ground_main_plane            -95.75720 -111.17214          260.14191
