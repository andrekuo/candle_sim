# %%
# %load_ext autoreload
# %autoreload 2
from qiskit_metal import draw, Dict, designs, MetalGUI
from qiskit_metal.designs.design_multiplanar import MultiPlanar
from qiskit_metal.toolbox_metal import math_and_overrides
from qiskit_metal.qlibrary.core import QComponent
import qiskit_metal as metal
# ?metal.qlibrary.core.QComponent.add_qgeometry

design = MultiPlanar()
gui = metal.MetalGUI(design)
design.overwrite_enabled = True

# dir(QComponent)
cpw_width = '11.7um'

design._chips.main.size.size_x = '5mm'
design._chips.main.size.size_y = '5mm'
from qiskit_metal.qlibrary.terminations.launchpad_wb import LaunchpadWirebond
from qiskit_metal.qlibrary.terminations.short_to_ground import ShortToGround
from qiskit_metal.qlibrary.tlines.straight_path import RouteStraight
from qiskit_metal.qlibrary.tlines.anchored_path import RouteAnchors
from qiskit_metal.qlibrary.tlines.mixed_path import RouteMixed
from qiskit_metal.qlibrary.qubits.transmon_cross import TransmonCross
from qiskit_metal.qlibrary.tlines.meandered import RouteMeander
from qiskit_metal.qlibrary.terminations.open_to_ground import OpenToGround
from qiskit_metal.qlibrary.couplers.coupled_line_tee import CoupledLineTee
from qiskit_metal.qlibrary.couplers.cap_n_interdigital_tee import CapNInterdigitalTee
from qiskit_metal.qlibrary.couplers.line_tee import LineTee

from collections import OrderedDict

import numpy as np
### Top and Bottom
options = Dict(
    orientation = -90,
    pos_y = 2.5 - 0.3,
    # pad_width = '80um',
    # pad_length = '200um',
    # taper_height = '200um',
    trace_width = cpw_width,
    trace_gap = '5.1um'
)
wb1 = LaunchpadWirebond(design, 'wb_top', options=options)

options = Dict(
    orientation = 90,
    pos_y = -2.5 + 0.3,
    # pad_width = '80um',
    # pad_length = '200um',
    # taper_height = '200um',
    trace_width = cpw_width,
    trace_gap = '5.1um'
)
wb2 = LaunchpadWirebond(design, 'wb_bottom', options=options)
xmon1_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '215um',
                 ground_spacing = '10um', 
                 claw_gap = '5.1um', 
                 claw_width = '15um',
                 claw_cpw_length = 0),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30um',
    cross_length = '240um',
    cross_gap = '30um',
    orientation = '-90',
    pos_x = '-1500um',
    pos_y = '1200um',
    aedt_hfss_inductance = 10.609327935963474E-9
)

# Create a new Transmon Cross object with name 'Q1'
q1 = TransmonCross(design, 'Q3', options=xmon1_options)

# otg_options = dict(width = '5.85um', 
#                    gap = '5.1um', 
#                 #    termination_gap = '500um',
#                    pos_x='-30um',  
#                    pos_y='1313um', 
#                    orientation='90')

# otg = OpenToGround(design, 'open_to_ground', options=otg_options)


xmon2_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '185.9um',
                 ground_spacing = '4.1um', 
                 claw_gap = '5.1um', 
                 claw_width = '15.9um',
                 claw_cpw_length = 0),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30.9um',
    cross_length = '200.9um',
    cross_gap = '29.1um',
    orientation = '90',
    pos_x = '2000.9um',
    pos_y = '1700um',
    aedt_hfss_inductance = 10.181089091582427E-9
)

# Create a new Transmon Cross object with name 'Q1'
q2 = TransmonCross(design, 'Q6', options=xmon2_options)
xmon3_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '185um',
                 ground_spacing = '5um', 
                 claw_gap = '5.1um', 
                 claw_width = '10um',
                 claw_cpw_length = 0),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30um',
    cross_length = '200um',
    cross_gap = '30um',
    orientation = '-90',
    pos_x = '-2000um',
    pos_y = '-300um',
    aedt_hfss_inductance = 12.306527428119221E-9
)

# Create a new Transmon Cross object with name 'Q1'
q3 = TransmonCross(design, 'Q5', options=xmon3_options)
xmon4_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '215.9um',
                 ground_spacing = '9.1um', 
                 claw_gap = '5.1um', 
                 claw_width = '15.9um',
                 claw_cpw_length = 0),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30.9um',
    cross_length = '240.9um',
    cross_gap = '29.1um',
    orientation = '90',
    pos_x = '1500um',
    pos_y = '250um',
    aedt_hfss_inductance = 15.500517135714711E-9
)

# Create a new Transmon Cross object with name 'Q1'
q4 = TransmonCross(design, 'Q2', options=xmon4_options)
xmon5_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '215.9um',
                 ground_spacing = '9.1um', 
                 claw_gap = '5.1um', 
                 claw_width = '15.9um',
                 claw_cpw_length = '0'),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30.9um',
    cross_length = '240.9um',
    cross_gap = '29.1um',
    orientation = '-90',
    pos_x = '-1500um',
    pos_y = '-1500um',
    aedt_hfss_inductance = 14.261653403709703E-9
)

# Create a new Transmon Cross object with name 'Q1'
q5 = TransmonCross(design, 'Q1', options=xmon5_options)
xmon6_options = dict(
    connection_pads=dict(
        # a = dict( connector_location = '0', connector_type = '0'),
        # b = dict(connector_location = '90', connector_type = '0'),
        c = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '200.9um',
                 ground_spacing = '10.9um', 
                 claw_gap = '5.1um', 
                 claw_width = '10.9um',
                 claw_cpw_width = cpw_width,
                 claw_cpw_length = '0'),
        # d = dict(connector_location = '270', connector_type = '0'),
    ),
    cross_width = '30.9um',
    cross_length = '220.9um',
    cross_gap = '29.1um',
    orientation = '90',
    pos_x = '2000um',
    pos_y = '-1200um',
    aedt_hfss_inductance = 15.724568346403403E-9
)

# Create a new Transmon Cross object with name 'Q1'
q6 = TransmonCross(design, 'Q4', options=xmon6_options)
clt1_opts = Dict(prime_width = cpw_width,
                prime_gap = '5.1um',
                second_width = cpw_width,
                second_gap = '5.1um',
                coupling_space = '7.9um',
                coupling_length = '225um',
                open_termination = False,
                orientation = '-90',
                pos_y = '1200um',
                down_length = '50um')

clt1 = CoupledLineTee(design, 'clt3', clt1_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw1_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'clt3',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q3',
                                                  pin = 'c')),
                lead = Dict(end_straight = '70um',
                            # start_jogged_extension = jogsS),
                ),
                fillet = '49.9um',
                total_length = '3900um',#'3893.8166um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um',)
cpw1 = RouteMeander(design, 'cpw3', options = cpw1_opts)
ncap2_opts = Dict(pos_x = '0',
                  pos_y = '1700um',
                  orientation = '90',
                  prime_width = cpw_width,
                  prime_gap = '5.1um',
                  second_width = cpw_width,
                  second_gap = '5.1um',
                  cap_gap = '4.1um',
                  cap_width = '10.9um',
                  cap_gap_ground = '5.1um',
                  finger_length = '30.9um',
                  finger_count = '10',
                  cap_distance = '50.9um',
                  )

NCap2 = CapNInterdigitalTee(design, 'ncap6', options = ncap2_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw2_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap6',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q6',
                                                  pin = 'c')),
                lead = Dict(start_straight = '100um',
                            end_straight = '170um'),
                fillet = '49.9um',
                total_length = '8150um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw2 = RouteMeander(design, 'cpw6', options = cpw2_opts)
ncap3_opts = Dict(pos_x = '0',
                  pos_y = '-300um',
                  orientation = '-90',
                  prime_width = cpw_width,
                  prime_gap = '5.1um',
                  second_width = cpw_width,
                  second_gap = '5.1um',
                  cap_gap = '4.1um',
                  cap_width = '10.9um',
                  cap_gap_ground = '5.1um',
                  finger_length = '30.9um',
                  finger_count = '7',
                  cap_distance = '50.9um',
                  )

NCap3 = CapNInterdigitalTee(design, 'ncap5', options = ncap3_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw3_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap5',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q5',
                                                  pin = 'c')),
                lead = Dict(start_straight = '100um'),
                fillet = '49.9um',
                total_length = '8025um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw3 = RouteMeander(design, 'cpw5', options = cpw3_opts)
clt4_opts = Dict(prime_width = cpw_width,
                prime_gap = '5.1um',
                second_width = cpw_width,
                second_gap = '5.1um',
                coupling_space = '7.9um',
                coupling_length = '225um',
                open_termination = False,
                orientation = '90',
                pos_y = '250um',
                down_length = '50um')

clt4 = CoupledLineTee(design, 'clt2', clt4_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw4_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'clt2',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q2',
                                                  pin = 'c')),
                lead = Dict(end_straight = '70um',
                            # start_jogged_extension = jogsS),
                ),
                fillet = '49.9um',
                total_length = '3700um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw4 = RouteMeander(design, 'cpw2', options = cpw4_opts)
clt5_opts = Dict(prime_width = cpw_width,
                prime_gap = '5.1um',
                second_width = cpw_width,
                second_gap = '5.1um',
                coupling_space = '7.9um',
                coupling_length = '225um',
                open_termination = False,
                orientation = '-90',
                pos_y = '-1500um',
                down_length = '50um')

clt5 = CoupledLineTee(design, 'clt1', clt5_opts)

cpw_total_length = 5160 + 716 + 300 + 1881.18568
cpw_total_length = str(cpw_total_length) + 'um'
cpw5_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'clt1',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q1',
                                                  pin = 'c')),
                lead = Dict(start_straight = '10um',
                            end_straight = '70um'),
                #             ),
                fillet = '49.9um',
                total_length = '3550um', # '6776um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw5 = RouteMeander(design, 'cpw1', options = cpw5_opts)
ncap6_opts = Dict(pos_x = '0',
                  pos_y = '-1000um',
                  orientation = '90',
                  prime_width = cpw_width,
                  prime_gap = '5.1um',
                  second_width = cpw_width,
                  second_gap = '5.1um',
                  cap_gap = '4.1um',
                  cap_width = '10.9um',
                  cap_gap_ground = '5.1um',
                  finger_length = '30.9um',
                  finger_count = '4',
                  cap_distance = '50.9um',
                  )

NCap6 = CapNInterdigitalTee(design, 'ncap4', options = ncap6_opts)

cpw6_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap4',
                                                    pin = 'second_end'),
                                   end_pin = Dict(component = 'Q4',
                                                  pin = 'c')),
                lead = Dict(start_straight = '100um',
                            end_straight = '70um'),
                fillet = '49.9um',
                total_length = '8000um',
                trace_width = cpw_width,
                meander = Dict(spacing = '100um',
                               asymmetry = '-150um'),
                trace_gap = '5.1um')
cpw6 = RouteMeander(design, 'cpw4', options = cpw6_opts)
RouteStraight.get_template_options(design)
feedline_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'wb_top',
                                                        pin = 'tie'),
                                       end_pin = Dict(component = 'ncap6',
                                                      pin = 'prime_end')),
                     trace_width = cpw_width,
                     trace_gap = '5.1um')
feedline = RouteStraight(design, 'feedline', options = feedline_opts)

feedline_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap6',
                                                        pin = 'prime_start'),
                                       end_pin = Dict(component = 'ncap5',
                                                      pin = 'prime_start')),
                     trace_width = cpw_width,
                     trace_gap = '5.1um')
feedline2 = RouteStraight(design, 'feedline2', options = feedline_opts)

feedline_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap5',
                                                        pin = 'prime_end'),
                                       end_pin = Dict(component = 'ncap4',
                                                      pin = 'prime_end')),
                     trace_width = cpw_width,
                     trace_gap = '5.1um')
feedline3 = RouteStraight(design, 'feedline3', options = feedline_opts)

feedline_opts = Dict(pin_inputs = Dict(start_pin = Dict(component = 'ncap4',
                                                        pin = 'prime_start'),
                                       end_pin = Dict(component = 'wb_bottom',
                                                      pin = 'tie')),
                     trace_width = cpw_width,
                     trace_gap = '5.1um')
feedline4 = RouteStraight(design, 'feedline4', options = feedline_opts)
gui.rebuild()
gui.autoscale()
# gui.zoom_on_components(['clt5', 'Q5'])
# gui.screenshot()

# %% [markdown]
# # EPR Simulation (Qubit + Cavity)

# %%
from qiskit_metal.analyses.quantization import EPRanalysis
import pyEPR as epr

# %%
qubit_names = [f'Q{i}' for i in range(1,7)]
for name in qubit_names:
    Lj = design.components[name].options['aedt_hfss_inductance']
    design.components[name].options['hfss_inductance'] = Lj
design.rebuild()

# %%
#Simulate Q1 + bus coupling strength

eig_q12bus = EPRanalysis(design, "hfss")
hfss1 = eig_q12bus.sim.renderer
eig_q12bus.sim.setup.max_passes = 19
eig_q12bus.sim.setup.max_delta_f = 0.005
eig_q12bus.sim.setup.n_modes = 2

# Create sim setup vars
sim_setup_var_dict = dict()
for i, name in enumerate(qubit_names):
    i += 1
    key_Lj = f'Lj{i}'
    key_Cj = f'Cj{i}'
    sim_setup_var_dict[key_Lj] = str(design.components[name].options['hfss_inductance']) + ' H'
    sim_setup_var_dict[key_Cj] = str(design.components[name].options['hfss_capacitance']) + ' F'

eig_q12bus.sim.setup.vars = sim_setup_var_dict


gui.rebuild()  # line needed to propagate the updates from the qubit instance into the junction design table
gui.autoscale()

# %%
eig_q12bus.sim.setup
# Out:
# {'name': 'Setup',
#  'reuse_selected_design': True,
#  'reuse_setup': True,
#  'min_freq_ghz': 1,
#  'n_modes': 2,
#  'max_delta_f': 0.005,
#  'max_passes': 19,
#  'min_passes': 1,
#  'min_converged': 1,
#  'pct_refinement': 30,
#  'basis_order': 1,
#  'vars': {'Lj1': '1.4261653403709703e-08 H',
#   'Cj1': '0 F',
#   'Lj2': '1.5500517135714712e-08 H',
#   'Cj2': '0 F',
#   'Lj3': '1.0609327935963473e-08 H',
#   'Cj3': '0 F',
#   'Lj4': '1.5724568346403403e-08 H',
#   'Cj4': '0 F',
#   'Lj5': '1.2306527428119221e-08 H',
#   'Cj5': '0 F',
#   'Lj6': '1.0181089091582427e-08 H',
#   'Cj6': '0 F'}}

# %%
# %matplotlib inline

hfss = eig_q12bus.sim.renderer

for i, name in enumerate(qubit_names):
    i += 1

    ### Run ANSYS simulation
    if i == 4 or i == 5 or i == 6:
        open_terminations = [(f'cpw{i}', 'start')]
    else:
        open_terminations = []
    
    # Clear previous design and renderer new design
    eig_q12bus.sim.run(name="Q3RO_v4.0",
                       components=[f'Q{i}', f'cpw{i}'],
                       open_terminations=open_terminations)

    ### Plot convergences
    eig_q12bus.sim.plot_convergences()

    ### Run EPR Analysis
    hfss1 = eig_q12bus.sim.renderer
    pinfo1 = hfss1.pinfo

    eprd1 = epr.DistributedAnalysis(pinfo1)

    ℰ_elec = eprd1.calc_energy_electric()
    ℰ_elec_substrate = eprd1.calc_energy_electric(None, 'main')
    ℰ_mag = eprd1.calc_energy_magnetic()

    print(f"""
    ℰ_elec_all       = {ℰ_elec}
    ℰ_elec_substrate = {ℰ_elec_substrate}
    EPR of substrate = {ℰ_elec_substrate / ℰ_elec * 100 :.1f}%

    ℰ_mag    = {ℰ_mag}
    """)

    eig_q12bus.sim.print_run_args()
    
    eig_q12bus.setup.junctions = Dict()
    eig_q12bus.setup.junctions[f'jj{i}'] = Dict(rect=f'JJ_rect_Lj_Q{i}_rect_jj', 
                                                line=f'JJ_Lj_Q{i}_rect_jj_',
                                                Lj_variable=f'Lj{i}', 
                                                Cj_variable=f'Cj{i}')

    eig_q12bus.run_epr()
# Out:
# INFO 07:20PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 07:20PM [load_ansys_project]: 	Opened Ansys App
# INFO 07:20PM [load_ansys_project]: 	Opened Ansys Desktop v2021.1.0
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# d:\andre\candle_sim\cavityqubit_dariasmethod-clark_summer_labor_camp_andre.ipynb Cell 7 in 1
#      <a href='vscode-notebook-cell:/d%3A/andre/candle_sim/cavityqubit_dariasmethod-clark_summer_labor_camp_andre.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>     open_terminations = []
#      <a href='vscode-notebook-cell:/d%3A/andre/candle_sim/cavityqubit_dariasmethod-clark_summer_labor_camp_andre.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a> # Clear previous design and renderer new design
# ---> <a href='vscode-notebook-cell:/d%3A/andre/candle_sim/cavityqubit_dariasmethod-clark_summer_labor_camp_andre.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> eig_q12bus.sim.run(name="Q3RO_v4.0",
#      <a href='vscode-notebook-cell:/d%3A/andre/candle_sim/cavityqubit_dariasmethod-clark_summer_labor_camp_andre.ipynb#X10sZmlsZQ%3D%3D?line=15'>16</a>                    components=[f'Q{i}', f'cpw{i}'],
#      <a href='vscode-notebook-cell:/d%3A/andre/candle_sim/cavityqubit_dariasmethod-clark_summer_labor_camp_andre.ipynb#X10sZmlsZQ%3D%3D?line=16'>17</a>                    open_terminations=open_terminations)
#      <a href='vscode-notebook-cell:/d%3A/andre/candle_sim/cavityqubit_dariasmethod-clark_summer_labor_camp_andre.ipynb#X10sZmlsZQ%3D%3D?line=18'>19</a> ### Plot convergences
#      <a href='vscode-notebook-cell:/d%3A/andre/candle_sim/cavityqubit_dariasmethod-clark_summer_labor_camp_andre.ipynb#X10sZmlsZQ%3D%3D?line=19'>20</a> eig_q12bus.sim.plot_convergences()
#
# File c:\users\lfl\qiskit-metal\qiskit_metal\analyses\core\simulation.py:203, in QSimulation.run(self, *args, **kwargs)
#     199 def run(self, *args, **kwargs):
#     200     """Alias for run_sim() necessary to implement super-class method, while
#     201     preventing method name collision when sim and non-sim QAnalysis classes are inherited.
#     202     """
# --> 203     self.run_sim(*args, **kwargs)
#
# File c:\users\lfl\qiskit-metal\qiskit_metal\analyses\simulation\eigenmode.py:127, in EigenmodeSim.run_sim(self, name, components, open_terminations, port_list, jj_to_port, ignored_jjs, box_plus_buffer)
#     124 self.clear_data()
#     126 if not self.renderer_initialized:
# --> 127     self._initialize_renderer()
#     129 vars_to_initialize = self.setup.vars
#     130 renderer_design_name = self._render(
#     131     name=name,
#     132     solution_type='eigenmode',
#    (...)
#     138     box_plus_buffer=box_plus_buffer,
#     139     vars_to_initialize=vars_to_initialize)
#
# File c:\users\lfl\qiskit-metal\qiskit_metal\analyses\core\simulation.py:141, in QSimulation._initialize_renderer(self)
#     138 def _initialize_renderer(self):
#     139     """Starts the renderer by executing the routine of the selected renderer.
#     140     """
# --> 141     self.renderer.start()
#
# File c:\users\lfl\qiskit-metal\qiskit_metal\renderers\renderer_base\renderer_base.py:378, in QRenderer.start(self, force)
#     373         self._close_renderer()
#     375 # TODO: move the code line below to inside the `if force or not initiated`,
#     376 #  but only after the TODO before the `if` is completed
#     377 # try to initialize the renderer
# --> 378 self.initiated = self._initiate_renderer()
#     380 return self.initiated
#
# File c:\users\lfl\qiskit-metal\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:307, in QAnsysRenderer._initiate_renderer(self)
#     305 if self.rdesktop.project_count() == 0:
#     306     self.rdesktop.new_project()
# --> 307 self.connect_ansys()  # TODO: can this be done differently?
#     309 # return True to indicate successful completion
#     310 return True
#
# File c:\users\lfl\qiskit-metal\qiskit_metal\renderers\renderer_ansys\ansys_renderer.py:410, in QAnsysRenderer.connect_ansys(self, project_path, project_name, design_name)
#     407 import pythoncom
#     409 try:
# --> 410     self._pinfo = epr.ProjectInfo(
#     411         do_connect=True,
#     412         project_path=self._options["project_path"]
#     413         if not project_path else project_path,
#     414         project_name=self._options["project_name"]
#     415         if not project_name else project_name,
#     416         design_name=self._options['design_name']
#     417         if not design_name else design_name)
#     418 except pythoncom.com_error as error:  # pylint: disable=no-member
#     419     print("com_error: ", error)
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pyEPR\project_info.py:224, in ProjectInfo.__init__(self, project_path, project_name, design_name, setup_name, dielectrics_bulk, dielectric_surfaces, resistive_surfaces, seams, do_connect)
#     221 self.setup = None
#     223 if do_connect:
# --> 224     self.connect()
#     225     self.dissipative['pinfo'] = self
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pyEPR\project_info.py:360, in ProjectInfo.connect(self)
#     354 def connect(self):
#     355     """
#     356     Do establish connection to Ansys desktop.
#     357     Connects to project and then get design and setup
#     358     """
# --> 360     self.connect_project()
#     361     if not self.project:
#     362         logger.info('\tConnection to Ansys NOT established.  \n')
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pyEPR\project_info.py:254, in ProjectInfo.connect_project(self)
#     245 """Sets
#     246 self.app
#     247 self.desktop
#    (...)
#     250 self.project_path
#     251 """
#     252 logger.info('Connecting to Ansys Desktop API...')
# --> 254 self.app, self.desktop, self.project = ansys.load_ansys_project(
#     255     self.project_name, self.project_path)
#     257 if self.project:
#     258     # TODO: should be property?
#     259     self.project_name = self.project.name
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pyEPR\ansys.py:3263, in load_ansys_project(proj_name, project_path, extension)
#    3259         project = None
#    3261 if project:
#    3262     logger.info(
# -> 3263         f"\tOpened Ansys Project\n\tFolder:    {project.get_path()}\n\tProject:   {project.name}"
#    3264     )
#    3265 else:
#    3266     logger.info(f"\tAnsys Project was not found.\n\t Project is None.")
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\lib\site-packages\pyEPR\ansys.py:571, in HfssProject.get_path(self)
#     569     return self._project.GetPath()
#     570 else:
# --> 571     raise Exception('''Error: HFSS Project does not have a path.
#     572 Either there is no HFSS project open, or it is not saved.''')
#
# Exception: Error: HFSS Project does not have a path.
#         Either there is no HFSS project open, or it is not saved.
