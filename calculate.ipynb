# %%
# %matplotlib inline
import pyEPR as epr
# plot the figures in the notebook. 

pinfo = epr.Project_Info()
# This is the core object for interacting with HFSS
# and running analysis within HFSS.
eprh = epr.DistributedAnalysis(pinfo) # epr hfss analysis 


# This is the core object for working with post processing data from HFSS
# This iwll load the saved solutions from above
fname = 'c:\data-pyEPR\CavityQubit_Modified_Candle_Andre_proj_0_1_5\Q3RO_v5.0_hfss\\2023-08-11 02-30-33.npz'
epra = epr.QuantumAnalysis(fname)

# Analyze 
epra.analyze_all_variations(cos_trunc = 8, fock_trunc = 15)
# Out:
# INFO 02:57PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 02:57PM [load_ansys_project]: 	Opened Ansys App
# INFO 02:57PM [load_ansys_project]: 	Opened Ansys Desktop v2021.1.0
# INFO 02:57PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/lfl/Documents/Ansoft/CavityQubit_Modified_Candle_Andre_proj_0_1_5.aedtresults/
# 	Project:   Airbridge_sim_08_11_wm1
# INFO 02:57PM [connect_design]: 	Opened active design
# 	Design:    Design_q3d5 [Solution type: Q3D]
# INFO 02:57PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.AnsysQ3DSetup'>)
# INFO 02:57PM [connect]: 	Connected to project "Airbridge_sim_08_11_wm1" and design "Design_q3d5" 😀
#
# WARNING 02:57PM [__init__]: <p>Error: <class 'IndexError'></p>
# Design "Design_q3d5" info:
# 	# eigenmodes    0
# 	# variations    0
# 	 Differences in variations:
#
#
#
#  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# Variation 0
#
# Starting the diagonalization
# Finished the diagonalization
# Pm_norm=
# modes
# 0    1.016172
# 1    1.019688
# dtype: float64
#
# Pm_norm idx =
#      jj2
# 0   True
# 1  False
# *** P (participation matrix, not normlz.)
#         jj2
# 0  0.972350
# 1  0.000712
#
# *** S (sign-bit matrix)
#    s_jj2
# 0      1
# 1      1
# *** P (participation matrix, normalized.)
#       0.99
#    0.00071
#
# *** Chi matrix O1 PT (MHz)
#     Diag is anharmonicity, off diag is full cross-Kerr.
#        141     0.33
#       0.33 0.000193
#
# *** Chi matrix ND (MHz)
#        154    0.304
#      0.304 0.000161
#
# *** Frequencies O1 PT (MHz)
# 0    3956.844726
# 1    6634.810551
# dtype: float64
#
# *** Frequencies ND (MHz)
# 0    3951.508594
# 1    6634.813441
# dtype: float64
#
# *** Q_coupling
# Empty DataFrame
# Columns: []
# Index: [0, 1]
# c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_quantum_analysis.py:712: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Q_coupling'] = self.Qm_coupling[variation][self.Qm_coupling[variation].columns[junctions]][modes]#TODO change the columns to junctions
# c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_quantum_analysis.py:717: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   result['Qs'] = self.Qs[variation][self.PM[variation].columns[junctions]][modes] #TODO change the columns to junctions
# OrderedDict([('0',
#               OrderedDict([('f_0', 0    4098.305624
#                             1    6634.975674
#                             Name: 0, dtype: float64),
#                            ('f_1',
#                             0    3956.844726
#                             1    6634.810551
#                             dtype: float64),
#                            ('f_ND',
#                             0    3951.508594
#                             1    6634.813441
#                             dtype: float64),
#                            ('chi_O1',
#                                         0         1
#                             0  141.295967  0.329861
#                             1    0.329861  0.000193),
#                            ('chi_ND',
#                                         0         1
#                             0  154.313718  0.303640
#                             1    0.303640  0.000161),
#                            ('ZPF',
#                             array([[0.37359218],
#                                    [0.0127639 ]])),
#                            ('Pm_normed',
#                             array([[9.88074913e-01],
#                                    [7.12403991e-04]])),
#                            ('Pm_raw',
#                             0    0.972350
#                             1    0.000712
#                             Name: jj2, dtype: float64),
#                            ('_Pm_norm',
#                             modes
#                             0    1.016172
#                             1    1.019688
#                             dtype: float64),
#                            ('_Pm_cap_norm',
#                             modes
#                             0    0.459275
#                             1    0.497700
#                             dtype: float64),
#                            ('hfss_variables',
#                             _Cj1                         0f
#                             _Cj2                         0f
#                             _Cj3                         0f
#                             _Cj4                         0f
#                             _Cj5                         0f
#                             _Cj6                         0f
#                             _Lj1    9.6859999999999998e-09H
#                             _Lj2                1.1268e-08H
#                             _Lj3                1.0471e-08H
#                             _Lj4    1.3815999999999999e-08H
#                             _Lj5    1.3235000000000001e-08H
#                             _Lj6    1.2679000000000001e-08H
#                             Name: 0, dtype: object),
#                            ('Ljs',
#                             jj2    1.126800e-08
#                             Name: 0, dtype: float64),
#                            ('Cjs',
#                             jj2    2.000000e-15
#                             Name: 0, dtype: float64),
#                            ('Q_coupling',
#                             Empty DataFrame
#                             Columns: []
#                             Index: [0, 1]),
#                            ('Qs',
#                             0    inf
#                             1    inf
#                             Name: 0, dtype: float64),
#                            ('fock_trunc', 15),
#                            ('cos_trunc', 8)]))])

# %%
eprh.hfss_report_full_convergence();
# Out:
# INFO 09:38PM [__del__]: Disconnected from Ansys HFSS
# INFO 09:38PM [hfss_report_full_convergence]: Creating report for variation 0
# INFO 09:38PM [hfss_report_f_convergence]: Saved convergences to C:\data-pyEPR\Airbridge_sim_08_11_wm1\Q3RO_v5.0_hfss\hfss_eig_f_convergence.csv

# %%
# Do EPR analysis for all modes and all variations 
# If you want to only analze a certain variation, you can change the 
# default keyword argeumetns variations=None, modes=None
eprh.do_EPR_analysis();
# Out:
# c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\project_info.py:239: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   options=pd.Series(get_instance_vars(self.options)),
# Variation 0  [1/1]
# c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_distributed_analysis.py:1101: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Ljs = pd.Series({})
# c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_distributed_analysis.py:1102: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Cjs = pd.Series({})
# c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_distributed_analysis.py:1245: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _Om = pd.Series({})
#   Mode 0 at 3.66 GHz   [1/2]
#     Calculating ℰ_magnetic,ℰ_electric
#        (ℰ_E-ℰ_H)/ℰ_E       ℰ_E       ℰ_H
#                99.0%  1.598e-26  1.56e-28
#
#     Calculating junction energy participation ration (EPR)
# 	method=`line_voltage`. First estimates:
# 	junction        EPR p_0j   sign s_0j    (p_capacitive)
# 		(U_tot_cap-U_tot_ind)/mean=98.07%
# WARNING: This simulation must not have converged well!!!                The difference in the total cap and ind energies is larger than 10%.                Proceed with caution.
# c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_distributed_analysis.py:981: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Sj = pd.Series({})
# c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_distributed_analysis.py:1054: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   Pj = pd.Series(OrderedDict([(j_name, Uj_ind/U_norm)
# c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_distributed_analysis.py:1057: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   PCj = pd.Series(OrderedDict([(j_name, Uj_cap/U_norm)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[18], line 4
#       1 # Do EPR analysis for all modes and all variations
#       2 # If you want to only analze a certain variation, you can change the
#       3 # default keyword argeumetns variations=None, modes=None
# ----> 4 eprh.do_EPR_analysis();
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_distributed_analysis.py:1285, in DistributedAnalysis.do_EPR_analysis(self, variations, modes, append_analysis)
#    1280 print(
#    1281     f'    Calculating junction energy participation ration (EPR)\n\tmethod=`{self.pinfo.options.method_calc_P_mj}`. First estimates:')
#    1282 print(
#    1283     f"\t{'junction':<15s} EPR p_{mode}j   sign s_{mode}j    (p_capacitive)")
# -> 1285 Pm[mode], Sm[mode], Pm_cap[mode], I_peak[mode], V_peak[mode], ansys_energies[mode] = self.calc_p_junction(
#    1286     variation, self.U_H/2., self.U_E/2., Ljs, Cjs)
#    1288 # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#    1289 # EPR Dissipative calculations -- should be a function block below
#    1290
#    1291 # TODO: this should really be passed as argument  to the functions rather than a
#    1292 # property of the calss I would say
#    1293 self.omega = 2*np.pi*freqs_bare_GHz[mode]
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_distributed_analysis.py:1065, in DistributedAnalysis.calc_p_junction(self, variation, U_H, U_E, Ljs, Cjs)
#    1057 PCj = pd.Series(OrderedDict([(j_name, Uj_cap/U_norm)
#    1058                              for j_name, Uj_cap in U_J_caps.items()]))
#    1060 # print('\t{:<15} {:>8.6g} {:>5s}'.format(
#    1061 #    j_name,
#    1062 #    Pj['p_' + j_name],
#    1063 #    '+' if Sj['s_' + j_name] > 0 else '-'))
# -> 1065 return Pj, Sj, PCj, pd.Series(I_peak), pd.Series(V_peak), \
#    1066     {'U_J_inds': U_J_inds,
#    1067      'U_J_caps': U_J_caps,
#    1068      'U_H': U_H,
#    1069      'U_E': U_E,
#    1070      'U_tot_ind': U_tot_ind,
#    1071      'U_tot_cap': U_tot_cap,
#    1072      'U_norm': U_norm,
#    1073      'U_diff': U_diff}
#
# UnboundLocalError: cannot access local variable 'I_peak' where it is not associated with a value

# %%
# %matplotlib inline
# plot the figures in the notebook. 

# This is the core object for working with post processing data from HFSS
# This iwll load the saved solutions from above
epra = epr.QuantumAnalysis(eprh.data_filename)

# Analyze 
epra.analyze_all_variations(cos_trunc = 8, fock_trunc = 15)
epra.plot_hamiltonian_results();
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 6
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 # plot the figures in the notebook.
#       3
#       4 # This is the core object for working with post processing data from HFSS
#       5 # This iwll load the saved solutions from above
# ----> 6 epra = epr.QuantumAnalysis(eprh.data_filename)
#       8 # Analyze
#       9 epra.analyze_all_variations(cos_trunc = 8, fock_trunc = 15)
#
# File c:\Users\lfl\.conda\envs\qiskit_metal\Lib\site-packages\pyEPR\core_quantum_analysis.py:236, in QuantumAnalysis.__init__(self, data_filename, variations, do_print_info, Res_hamil_filename)
#     232 self.data_filename = data_filename
#     233 self.results = HamiltonianResultsContainer(dict_file=Res_hamil_filename,
#     234                                            data_dir=data_filename)
# --> 236 with open(str(data_filename), 'rb') as handle:
#     237     # Contain everything: project_info and results
#     238     self.data = Dict(pickle.load(handle))
#     240 # Reverse from variations on outside to on inside
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\data-pyEPR\\Airbridge_sim_08_11_wm1\\Q3RO_v5.0_hfss\\2023-08-12 11-51-39.npz'
